# %%
import io
import os
import panel as pn
import numpy as np
import pandas as pd

pn.extension()
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %% [markdown]
# ### Option 1: Simple button upload

# %%
upload = pn.widgets.FileInput()
upload
# Out:
# FileInput()

# %%
upload.value
# Out:
# b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Thu Feb  6 12:00:52 2020                                        \x00\x00\x00\x00\x00\x00\x00\x00\x00\x01IM\x0f\x00\x00\x00"I\x01\x00x\x9c,Y\t8\x16\xdf\x17\xa6\xa2E\xd1\xaeTRZ\x14i\x95h;iQBHT$\xa5\x88P(\xb4\xd8+!E\xa8l\x11"K\x92\xd4 \x89\xaf\x18ch\x916\xa5h\xb3\x94\xadE\xfc\xa8\xfe\xef\xf7\xf9\xf7<\x9e\xe9\x9a;\xe7\x9e\xf3\x9e\xf7l\x97\xb4\x98\x98X\x96\xa7\xb8\x98$\x9e\x83\xf0#|\n\xffI\xfc\x7f\x9d\x83\x9f5\xf8\x11\x17\x1b \xb6g\xd7\xa1]\x83\xf1\x7fo\xec\xbf+CvR\xa6\x1cI\xce\xfdoH\xfe&\x8e\x9a:\x8eEG-\xe2\xc8\xf1\xd4\x84vqC\x8e\xce\x87\xde\xca\xfag\xc6\xd1\x7fO$~]\x8d\xe5\xe8\xc5\x87\xcdb\'\xeer\xb41kILj\x04Gm\xdc\x03\xadI\xa1\x1cm5\x89\n\xcf\xac\xe0(\xc6\xc1Q\xf7\xf1\x05\x8e\xa2\x06M\xb8<#\x88\xa3-I\x82W\xbb\x839:\xd7[\\\xf4\xde\x91\xa3\x9e\xc6\xea\x08\x06r\xf3\xfd^E\xde\xd9\xc1\xd1$\x85K\x89V\xfb8z\x97n2C\xc1\x8e\xa39\x8f\xfd\xee.\x8c\xe6(0\xbd\xbc0,\x8a\xa3S[\nB\xbb\xe39\xaao\xcd\xa8]\x1c\xc2\xd1\x89a\x9bnd\x1c\xe1h\xd1K\xdb\xa4\
# ...

# %%
# how it will look in the app
panel = pn.template.GoldenTemplate(title='INCF', sidebar_width=40, header_background='#DAEAF1')

css = """ 
.title{color:#3C2C3E !important; }
"""

pn.extension(raw_css=[css])
panel.show()
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# Launching server at http://localhost:60045
