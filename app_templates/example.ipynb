# %%
import sys
import warnings
import panel as pn
import numpy as np

# DO NOT remove this line below, otherwise the app won't be found
sys.path.append('..')
warnings.filterwarnings('ignore')

# %%
import sim2bids
from sim2bids.sim2bids import MainArea
from sim2bids.generate import models
from sim2bids.app import app

pn.extension('tabulator', 'ace', 'jsoneditor', 'ipywidgets', sizing_mode='stretch_width', notifications=True)
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# NotificationArea(sizing_mode='stretch_width')

# %%
# incf edu
app.SoftwareVersion = 2.6
app.SoftwareRepository = 'https://github.com/the-virtual-brain/tvb-root/releases/tag/2.6'
app.SoftwareName = 'TVB'

# run the app
pn.serve(MainArea().view())
# Out:
# WARNING:param.MainArea00149: Setting non-parameter attribute text_input=TextInput(name='Insert Path', sizing_mode='stretch_width') using a mechanism intended only for parameters
# WARNING:param.MainArea00149:Setting non-parameter attribute text_input=TextInput(name='Insert Path', sizing_mode='stretch_width') using a mechanism intended only for parameters
# WARNING:param.MainArea00149: Setting non-parameter attribute cross_select=CrossSelector(options=['.ipynb_checkpoints', ...], sizing_mode='stretch_width') using a mechanism intended only for parameters
# WARNING:param.MainArea00149:Setting non-parameter attribute cross_select=CrossSelector(options=['.ipynb_checkpoints', ...], sizing_mode='stretch_width') using a mechanism intended only for parameters
# INFO:bokeh.server.server:Starting Bokeh server version 2.4.3 (running on Tornado 6.2)
# INFO:bokeh.server.tornado:User authentication hooks NOT provided (default user enabled)
# Launching server at http://localhost:56556
# INFO:tornado.access:200 GET / (::1) 209.01ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/jsoneditor/jsoneditor@9.5.6/dist/jsoneditor.min.css (::1) 81.18ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/datatabulator/tabulator-tables@5.3.2/dist/css/tabulator_simple.min.css (::1) 4.22ms
# INFO:tornado.access:200 GET /static/extensions/panel/css/dataframe.css (::1) 10.77ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/notificationarea/notyf@3/notyf.min.css (::1) 13.65ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/font-awesome/css/all.min.css (::1) 21.82ms
# INFO:tornado.access:200 GET /static/extensions/panel/css/alerts.css (::1) 26.83ms
# INFO:tornado.access:200 GET /static/extensions/panel/css/card.css (::1) 30.73ms
# INFO:tornado.access:200 GET /static/extensions/panel/css/debugger.css (::1) 4.01ms
# INFO:tornado.access:200 GET /static/extensions/panel/css/json.css (::1) 8.20ms
# INFO:tornado.access:200 GET /static/extensions/panel/css/loading.css (::1) 7.72ms
# INFO:tornado.access:200 GET /static/extensions/panel/css/markdown.css (::1) 12.71ms
# INFO:tornado.access:200 GET /static/extensions/panel/css/widgets.css (::1) 16.81ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/css/material-components-web@7.0.0/dist/material-components-web.min.css (::1) 5.51ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/materialtemplate/material.css (::1) 13.51ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/defaulttheme/default.css (::1) 9.31ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/materialtemplate/default.css (::1) 15.31ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/jsoneditor/jsoneditor@9.5.6/dist/jsoneditor.min.js (::1) 30.41ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/datatabulator/luxon/build/global/luxon.min.js (::1) 5.52ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/datatabulator/tabulator-tables@5.3.2/dist/js/tabulator.js (::1) 20.04ms
# INFO:tornado.access:200 GET /static/js/bokeh.min.js?v=3c61e952b808bb7e346ce828a565a5f23aaf7708d034fa9d0906403813355d45bb4e8d8b0b23a93f032c76831d4f0221846f28699c7f5147caa62e0d31668314 (::1) 29.74ms
# INFO:tornado.access:200 GET /static/js/bokeh-gl.min.js?v=e5df31fd9010eacff0aa72d315264604b5e34972ba445acea6fce98080eecf33acf2d2986126360faaa5852813cffa16f6f6f4889923318300f062497c02da4e (::1) 29.69ms
# INFO:tornado.access:200 GET /static/js/bokeh-widgets.min.js?v=8a1ff6f5aa0d967f4998d275803bbb111d928fd9f605ef9e1f30cfd021df0e77224ee3d13f83edb3a942f6e4ccc569ee5dd8951a8aa6cb600602463b90c65a87 (::1) 35.24ms
# INFO:tornado.access:200 GET /static/js/bokeh-tables.min.js?v=ae2903e57cf57f52819fdf4d938c648982b51c34f73b6e653a0f3bb3c8ab44f338505931ace43eafc1636e215492e2314acf54c54baffb47813b86b4923a7fe0 (::1) 48.29ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/notificationarea/notyf@3/notyf.min.js (::1) 9.65ms
# INFO:tornado.access:200 GET /static/extensions/panel/panel.min.js?v=0f8d7ed5b1114c4abe733b1a6a147ff6e923df5ad710f6d6eb9b8b30129543eb (::1) 17.54ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/js/material-components-web@7.0.0/dist/material-components-web.min.js (::1) 30.16ms
# INFO:tornado.access:101 GET /ws (::1) 3.13ms
# INFO:bokeh.server.views.ws:WebSocket connection opened
# INFO:bokeh.server.views.ws:ServerConnection created
# INFO:tornado.access:200 GET /static/extensions/panel/images/favicon.ico (::1) 7.07ms
# INFO:bokeh.server.views.ws:WebSocket connection closed: code=1001, reason=None
